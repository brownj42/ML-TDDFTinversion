# %%
import sys
sys.path.insert(0, "/home/jbrown/Documents/Coding/tddft-inversion-release/python")
import TDDFTinversion as td
import numpy as np

# %%
np1=101 #number of grid points for 1-dimension
#initialize systemparameters derived type
sysparams=td.derivedtypes.init_systemparameters(np1)
sysparams.np1=np1 #number of grid points for 1-dimension
sysparams.nd=1 #number of dimensions
sysparams.npart=2 #number of particles
sysparams.xmin=-15 #minimum grid point
sysparams.xmax=15 #maximum grid point
sysparams.ct=0. #starting time
sysparams.dth=0.005 #goal time step
sysparams.dvksmax=100000000 #max derivative of density with respect to time
sysparams.pinv0minresqlp1=1 #pseudoinverse set to 0, minresqlp set to 1
sysparams.quantization=1 #Quantization
sysparams.energy=5. #Energy of KS system, this can if desired
td.derivedtypes.fill_systemparameters(sysparams)
td.keomod.buildkeo(sysparams) #build kinetic energy operator and lattice values

# %%
#generate derived type to store 1 and 2 body potentials
sharedvals=td.derivedtypes.init_sharedvalues(sysparams) #shared values derived type
#generate potentials, can write own program
td.potential.generate_1bodypot(sysparams,sharedvals)
td.potential.generate_2bodypot(sysparams,sharedvals)

#derived type that stores full wavefunction and potential
fullvals=td.derivedtypes.init_fullvalues(sysparams)
td.potential.generate_nbodypot(sysparams,sharedvals,fullvals)
td.initial_states.initializefullsystem(sysparams,fullvals)

# %%
#next 5 are required to develop and advance KS orbitals
dpe=np.zeros(sysparams.ntot1,dtype=np.float64) #current density
dnx=np.zeros(sysparams.ntot1,dtype=np.float64) #current derivative of density
ddnx=np.zeros(sysparams.ntot1,dtype=np.float64) #second derivative of density
dpenew=np.zeros(sysparams.ntot1,dtype=np.float64) #density after time step dt, taken from sysparams.dt
ddnxnew=np.zeros(sysparams.ntot1,dtype=np.float64) #second derivative of density after time step sysparams.dt

#placeholder for advancing full system
psinew=np.zeros(sysparams.ntot,dtype=np.complex128)

# %%
td.density.fullwf_density(sysparams,fullvals.psi,dpe)
#initialize KS orbitals system to match dpe
KSvals=td.initial_states.initializekssystem(sysparams,sharedvals,dpe,fullvals)

# %%
#add driving potential for example 2
if (sysparams.npart==2):
    td.potential.add_driving_potential(sysparams,sharedvals,fullvals)
    
sysparams.dt=sysparams.dth/2

# %%
rwave=np.zeros((1100,sysparams.npart,sysparams.ntot1),dtype=np.float64)
iwave=np.zeros((1100,sysparams.npart,sysparams.ntot1),dtype=np.float64)
densities=np.zeros((1100,sysparams.ntot1),dtype=np.float64)
ddensities=np.zeros((1100,sysparams.ntot1),dtype=np.float64)
potentials=np.zeros((1100,sysparams.ntot1),dtype=np.float64)
rwave[0]=np.real(np.transpose(KSvals.phi))
iwave[0]=np.imag(np.transpose(KSvals.phi))
densities[0]=dpe

# %%
for loop in range(1101):
    if (np.remainder(loop,50)==0):
        print('\n')
        print('For time '+str(sysparams.ct)+' to ',str(sysparams.ct+sysparams.dt))
    
    # generate wavefunction at ct+dt
    td.propagate.advancewf(sysparams,sharedvals,25,fullvals.v,fullvals.psi,psinew)
    
    #Calculate density, first derivative of density and second derivative of density 
    #at time ct using psi
    td.density.fullwf_density(sysparams,fullvals.psi,dpe)
    td.density.calcdnx(sysparams,sharedvals,sysparams.ntot1,fullvals.psi,fullvals.v,dnx)
    td.density.calcddnx(sysparams,sharedvals,sysparams.ntot1,fullvals.psi,fullvals.v,ddnx)
    
    #Calculate density and second derivative of density at time ct+dt using psinew
    td.density.fullwf_density(sysparams,psinew,dpenew)
    td.density.calcddnx(sysparams,sharedvals,sysparams.ntot1,psinew,fullvals.v,ddnxnew)
    
    if (loop>0): 
        rwave[loop-1]=np.real(np.transpose(KSvals.phi))
        iwave[loop-1]=np.imag(np.transpose(KSvals.phi))
        densities[loop-1]=ddnx
        potentials[loop-1]=KSvals.vks-sharedvals.v1
        ddensities[loop-1]=dnx
    
    #Attempt to advance KS system
    info=td.ksadvance_mod.advancekssystem(dpe,dpenew,dnx,ddnx,ddnxnew,loop+1,sysparams,KSvals,sharedvals)
    
    if (info==1):#succesful advance of orbitals shift full wavefunction
        fullvals.psi=psinew
# Out:
# For time 0.0 to  0.0025
#
#
# For time 0.24000000000000013 to  0.24500000000000013
#
#
# For time 0.4900000000000003 to  0.49500000000000033
#
#
# For time 0.7400000000000005 to  0.7450000000000006
#
#
# For time 0.9900000000000008 to  0.9950000000000008
#
#
# For time 1.2399999999999956 to  1.2449999999999954
#
#
# For time 1.4899999999999902 to  1.4949999999999901
#
#
# For time 1.739999999999985 to  1.7449999999999848
#
#
# For time 1.9899999999999796 to  1.9949999999999795
#
#
# For time 2.2399999999999745 to  2.2449999999999743
#
#
# For time 2.489999999999969 to  2.494999999999969
#
#
# For time 2.739999999999964 to  2.7449999999999637
#
#
# For time 2.9899999999999585 to  2.9949999999999584
#
#
# For time 3.239999999999953 to  3.244999999999953
#
#
# For time 3.489999999999948 to  3.4949999999999477
#
#
# For time 3.7399999999999425 to  3.7449999999999424
#
#
# For time 3.989999999999937 to  3.994999999999937
#
#
# For time 4.239999999999932 to  4.244999999999932
#
#
# For time 4.4899999999999265 to  4.494999999999926
#
#
# For time 4.739999999999921 to  4.744999999999921
#
#
# For time 4.989999999999916 to  4.994999999999916
#
#
# For time 5.2399999999999105 to  5.24499999999991
#
#
# For time 5.489999999999905 to  5.494999999999905

# %%
fulldata=np.zeros((1100,6*sysparams.ntot1),dtype=np.float64)

# %%
for i in range(1100):
    for j in range(1):
        fulldata[i][0:sysparams.ntot1]=densities[i]
        fulldata[i][sysparams.ntot1:2*sysparams.ntot1]=ddensities[i]
for i in range(1100):
    for j in range(2):
        fulldata[i][(j+2)*sysparams.ntot1:(j+3)*sysparams.ntot1]=rwave[i][j]
        fulldata[i][(j+4)*sysparams.ntot1:(j+5)*sysparams.ntot1]=iwave[i][j]

# %%
print(densities[100]-densities[1])
# Out:
# [ 2.30672785e-13  9.52633918e-12  2.65192923e-10  4.87598432e-09
#   6.13872391e-08  5.43209947e-07  3.46532745e-06  1.62996796e-05
#   5.76642037e-05  1.55971632e-04  3.26284791e-04  5.29704244e-04
#   6.58665524e-04  5.91526752e-04  2.89939488e-04 -1.51264578e-04
#  -5.56045539e-04 -7.76671369e-04 -7.69796925e-04 -5.93423708e-04
#  -3.49972886e-04 -1.27759107e-04  2.71368468e-05  1.08485881e-04
#   1.32976910e-04  1.23526282e-04  9.93531143e-05  7.27421909e-05
#   4.97526051e-05  3.22991611e-05  2.01212818e-05  1.21253490e-05
#   7.11196564e-06  4.08008614e-06  2.29858665e-06  1.27578682e-06
#   6.99521743e-07  3.79751605e-07  2.04503221e-07  1.09411591e-07
#   5.82337902e-08  3.08647182e-08  1.63061664e-08  8.59192452e-09
#   4.51926316e-09  2.37445676e-09  1.24953995e-09  6.63194620e-10
#   3.64435530e-10  2.24051393e-10  1.81507795e-10  2.18207092e-10
#   3.49394809e-10  6.31181975e-10  1.18201793e-09  2.23438353e-09
#   4.22528263e-09  7.97826960e-09  1.50201707e-08  2.81836367e-08
#   5.26554935e-08  9.78843947e-08  1.80835814e-07  3.31622610e-07
#   6.02696331e-07  1.08365105e-06  1.92345635e-06  3.36215801e-06
#   5.77083320e-06  9.69384484e-06  1.58741600e-05  2.52258025e-05
#   3.86925932e-05  5.69222024e-05  7.97061989e-05  1.05245398e-04
#   1.29507469e-04  1.46213883e-04  1.48103677e-04  1.29726753e-04
#   9.08928742e-05  3.84849712e-05 -1.58450429e-05 -6.20374163e-05
#  -9.74539404e-05 -1.25933971e-04 -1.49565216e-04 -1.62044226e-04
#  -1.53241037e-04 -1.21358780e-04 -7.81287707e-05 -3.99837391e-05
#  -1.59585009e-05 -4.87483420e-06 -1.11737606e-06 -1.88105236e-07
#  -2.27343963e-08 -1.92189688e-09 -1.10969161e-10 -4.18300441e-12
#  -1.19398971e-13]

# %%
traindata=np.zeros((900,6*sysparams.ntot1),dtype=np.float32)
trainlabels=np.zeros((900,sysparams.ntot1),dtype=np.float32)
testdata=np.zeros((200,6*sysparams.ntot1),dtype=np.float32)
testlabels=np.zeros((200,sysparams.ntot1),dtype=np.float32)
print(np.shape(trainlabels))
print(np.shape(traindata))
f=0
for i in range(100):
    trainlabels[f:f+9]=potentials[10*i:10*i+9]
    testlabels[i]=potentials[i+900]
    testlabels[i+100]=potentials[i+1000]
    traindata[f:f+9]=fulldata[10*i:10*i+9]
    testdata[i]=fulldata[i+900]
    testdata[i+100]=fulldata[i+1000]
    f=f+9
# Out:
# (900, 101)
# (900, 606)

# %%
import tensorflow as tf

# %%
inputs=tf.keras.Input(shape=(sysparams.ntot1*6,))
dense=tf.keras.layers.Dense(sysparams.ntot1*3,activation="linear")
x=dense(inputs)
x = tf.keras.layers.Dense(sysparams.ntot1, activation="linear")(x)
x = tf.keras.layers.Dense(6, activation="tanh")(x)
x = tf.keras.layers.Dense(6, activation="tanh")(x)
x = tf.keras.layers.Dense(6, activation="tanh")(x)
x = tf.keras.layers.Dense(6, activation="tanh")(x)
x = tf.keras.layers.Dense(6, activation="tanh")(x)
200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7870e-04
# Epoch 136/200
# 29/29 [==============================] - 0s 994us/step - loss: 1.7692e-04
# Epoch 137/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3928e-04
# Epoch 138/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4930e-04
# Epoch 139/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4339e-04
# Epoch 140/200
# 29/29 [==============================] - 0s 952us/step - loss: 1.5019e-04
# Epoch 141/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3931e-04
# Epoch 142/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5354e-04
# Epoch 143/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7203e-04
# Epoch 144/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6895e-04
# Epoch 145/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4293e-04
# Epoch 146/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7805e-04
# Epoch 147/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7847e-04
# Epoch 148/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4977e-04
# Epoch 149/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5061e-04
# Epoch 150/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5820e-04
# Epoch 151/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6069e-04
# Epoch 152/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6375e-04
# Epoch 153/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3560e-04
# Epoch 154/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3488e-04
# Epoch 155/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4227e-04
# Epoch 156/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4679e-04
# Epoch 157/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3747e-04
# Epoch 158/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4290e-04
# Epoch 159/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4383e-04
# Epoch 160/200
# 29/29 [==============================] - 0s 965us/step - loss: 1.3772e-04
# Epoch 161/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3672e-04
# Epoch 162/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4800e-04
# Epoch 163/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4953e-04
# Epoch 164/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9154e-04
# Epoch 165/200
# 29/29 [==============================] - 0s 978us/step - loss: 1.8651e-04
# Epoch 166/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7607e-04
# Epoch 167/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9692e-04
# Epoch 168/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7094e-04
# Epoch 169/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5141e-04
# Epoch 170/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3926e-04
# Epoch 171/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3550e-04
# Epoch 172/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3647e-04
# Epoch 173/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3858e-04
# Epoch 174/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3518e-04
# Epoch 175/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5329e-04
# Epoch 176/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4078e-04
# Epoch 177/200
# 29/29 [==============================] - 0s 945us/step - loss: 1.6296e-04
# Epoch 178/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9994e-04
# Epoch 179/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7346e-04
# Epoch 180/200
# 29/29 [==============================] - 0s 962us/step - loss: 1.7601e-04
# Epoch 181/200
# 29/29 [==============================] - 0s 945us/step - loss: 1.5002e-04
# Epoch 182/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4641e-04
# Epoch 183/200
# 29/29 [==============================] - 0s 927us/step - loss: 1.3810e-04
# Epoch 184/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8022e-04
# Epoch 185/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3128e-04
# Epoch 186/200
# 29/29 [==============================] - 0s 973us/step - loss: 1.4079e-04
# Epoch 187/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5018e-04
# Epoch 188/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4472e-04
# Epoch 189/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3700e-04
# Epoch 190/200
# 29/29 [==============================] - 0s 982us/step - loss: 1.4204e-04
# Epoch 191/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3057e-04
# Epoch 192/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4425e-04
# Epoch 193/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3573e-04
# Epoch 194/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4248e-04
# Epoch 195/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4275e-04
# Epoch 196/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3281e-04
# Epoch 197/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3275e-04
# Epoch 198/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4041e-04
# Epoch 199/200
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6359e-04
# Epoch 200/200
# 29/29 [==============================] - 0s 1ms/step - loss: 2.3199e-04

# %%
v=mlp.predict(testdata)

# %%
import matplotlib.pyplot as plt

# %%
x=sysparams.xlattice
plt.plot(x,testlabels[12]-3.83,x,v[12])
# Out:
# [<matplotlib.lines.Line2D at 0x7f69c046deb8>,
#  <matplotlib.lines.Line2D at 0x7f69c03fa048>]
